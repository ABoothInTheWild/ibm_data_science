# %%
import pandas as pd
import numpy as np

# %%
a=np.array([-1,1])

b=np.array([1,1])

np.dot(a,b)
# Out:
# np.int64(0)

# %%
X=np.array([[1,0,1],[2,2,2]])

out=X[0:2,2]

# %%
out
# Out:
# array([1, 2])

# %%
X
# Out:
# array([[1, 0, 1],
#        [2, 2, 2]])

# %%
X=np.array([[1,0],[0,1]])

Y=np.array([[2,2],[2,2]])

Z=np.dot(X,Y)

# %%
Z
# Out:
# array([[2, 2],
#        [2, 2]])

# %%
x = "Gone"

if x == "Go":

    print('Go')

else:

    print('Stop')

print('Mike')
# Out:
# Stop
# Mike
